# %%
# Resolução TPC 4

print ("1-Criar lista\n2-Ler Lista\n3-Soma\n4-Média\n5-Maior\n6-Menor\n7-Está Ordenada por ordem crescente\n8-Está ordenada por ordem decrescente\n9-Procura um elemento\n0-Sair")
menu = int (input ("Escolha a opção pretendida"))

while menu != 0 :
    if menu == 1:
        print ("Criar lista")
        N = int (input("tamanho da lista"))
        lista = []
        n = 0
        while n < N: 
            import random
            x = random.randrange (0,101)
            lista.append (x)
            n = n + 1
        print (lista) 
        menu = int (input ("Escolha a opção pretendida"))
    if menu == 2:
        print ("Ler Lista")
        N = int (input("tamanho da lista"))
        lista = []
        n = 0
        while n < N:
            x = int (input("introduza um número"))
            lista.append (x)
            n = n + 1
        print (lista)
        menu = int (input ("Escolha a opção pretendida"))
    if menu == 3:
        print ("Soma")
        soma = 0
        for n in lista:
            soma = soma + n
        print (soma)
        menu = int (input ("Escolha a opção pretendida"))
    if menu == 4:
        print ("Média")
        média = soma/len (lista)
        print (média)
        menu = int (input ("Escolha a opção pretendida"))
    if menu == 5:
        print ("Maior")
        maior = lista [0]
        for n in lista:
            if n > maior:
                maior = n
        print (maior)
        menu = int (input ("Escolha a opção pretendida"))
    if menu == 6:
        print ("Menor")
        menor = lista [0]
        for n in lista: 
            if n < menor:
                menor = n
        print (menor)
        menu = int (input ("Escolha a opção pretendida"))
    if menu == 7:
        print ("Está Ordenada por Ordem Crescente?")
        maior = lista [0]
        for n in lista:
            if n > maior:
                maior = n
        menor = lista [0]
        for n in lista: 
            if n < menor:
                menor = n
        if menor == lista [0] and maior == lista [-1]:
            print ("Sim!")
        else: print ("Não!")
        menu = int (input ("Escolha a opção pretendida"))
    if menu == 8 :
        print ("Está Ordenada por ordem descrescente?")
        maior = lista [0]
        for n in lista:
            if n > maior:
                maior = n
        menor = lista [0]
        for n in lista: 
            if n < menor:
                menor = n
        if menor == lista [-1] and maior == lista [0]:
            print ("Sim!")
        else: print ("Não!")
        menu = int (input ("Escolha a opção pretendida"))
    if menu == 9:
        print ("Procura um elemento")
        x = int (input("Introduz o elemento a procurar"))
        if x in lista:
            print ("O elemento encontra-se na posição", lista.index(x))
        else: print (-1, "O elemento não se encontra.")
        menu = int (input ("Escolha a opção pretendida"))
    



if menu == 0:
    print ("Sair")
    print (lista)
# Out:
# 1-Criar lista
# 2-Ler Lista
# 3-Soma
# 4-Média
# 5-Maior
# 6-Menor
# 7-Está Ordenada por ordem crescente
# 8-Está ordenada por ordem decrescente
# 9-Procura um elemento
# 0-Sair
# Criar lista
# [43, 8, 9, 18]
# Procura um elemento
# O elemento encontra-se na posição 2
# Está Ordenada por ordem descrescente?
# Não!
# Procura um elemento
# O elemento encontra-se na posição 1
# Procura um elemento
# -1 O elemento não se encontra.
# Sair
# [43, 8, 9, 18]
